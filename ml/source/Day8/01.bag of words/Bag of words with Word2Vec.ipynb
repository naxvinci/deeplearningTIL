# %% [markdown]
# ## Part 1 - Preprocessing

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import re
from bs4 import BeautifulSoup
import pandas as pd       
train = pd.read_csv("labeledTrainData.tsv", header=0, delimiter="\t", quoting=3)
test = pd.read_csv("testData.tsv", header=0, delimiter="\t", quoting=3)
unlabeled_train = pd.read_csv("unlabeledTrainData.tsv", header=0, delimiter="\t", quoting=3)

# %%
print(train.shape)
print(test.shape)
print(unlabeled_train.shape)

print(train['review'].size)
print(test['review'].size)
print(unlabeled_train['review'].size)
# Out:
# (25000, 3)
# (25000, 2)
# (50000, 2)
# 25000
# 25000
# 50000

# %%
train.head()
# Out:
#          id  sentiment                                             review
# 0  "5814_8"          1  "With all this stuff going down at the moment ...
# 1  "2381_9"          1  "\"The Classic War of the Worlds\" by Timothy ...
# 2  "7759_3"          0  "The film starts with a manager (Nicholas Bell...
# 3  "3630_4"          0  "It must be assumed that those who praised thi...
# 4  "9495_8"          1  "Superbly trashy and wondrously unpretentious ...

# %%
test.head()
# Out:
#            id                                             review
# 0  "12311_10"  "Naturally in a film who's main themes are of ...
# 1    "8348_2"  "This movie is a disaster within a disaster fi...
# 2    "5828_4"  "All in all, this is a movie for kids. We saw ...
# 3    "7186_2"  "Afraid of the Dark left me with the impressio...
# 4   "12128_7"  "A very accurate depiction of small time mob l...

# %%
train['sentiment'].value_counts()
# Out:
# 1    12500
# 0    12500
# Name: sentiment, dtype: int64

# %%
from Word2VecUtil import Word2VecUtil

# %%
Word2VecUtil.review_to_wordlist(train['review'][0])[:10]
# Out:
# ['with', 'all', 'this', 'stuff', 'go', 'down', 'at', 'the', 'moment', 'with']

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\student\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
sentences = []
for review in train["review"]:
    sentences += Word2VecUtil.review_to_sentences(
        review, remove_stopwords=False)

# %%
for review in unlabeled_train["review"]:
    sentences += Word2VecUtil.review_to_sentences(
        review, remove_stopwords=False)

len(sentences)
# Out:
# 795538

# %%
sentences[0][:10]
# Out:
# ['with', 'all', 'this', 'stuff', 'go', 'down', 'at', 'the', 'moment', 'with']

# %%
sentences[1][:10]
# Out:
# ['mayb', 'i', 'just', 'want', 'to', 'get', 'a', 'certain', 'insight', 'into']

# %% [markdown]
# ## Part 2 - Word2Vec

# %%
import logging
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', 
                    level=logging.INFO)

# %%
# 파라메터값 지정
num_features = 300 # 문자 벡터 차원 수
min_word_count = 40 # 최소 문자 수
num_workers = 4 # 병렬 처리 스레드 수
context = 10 # 문자열 창 크기
downsampling = 1e-3 # 문자 빈도 수 Downsample

# 초기화 및 모델 학습
from gensim.models import word2vec

# 모델 학습
model = word2vec.Word2Vec(sentences, 
                          workers=num_workers, 
                          size=num_features, 
                          min_count=min_word_count,
                          window=context,
                          sample=downsampling)
model
# Out:
# 2020-04-30 11:47:52,059: INFO: collecting all words and their counts
# 2020-04-30 11:47:52,061: INFO: PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2020-04-30 11:47:52,119: INFO: PROGRESS: at sentence #10000, processed 225803 words, keeping 12465 word types
# 2020-04-30 11:47:52,181: INFO: PROGRESS: at sentence #20000, processed 451892 words, keeping 17070 word types
# 2020-04-30 11:47:52,221: INFO: PROGRESS: at sentence #30000, processed 671314 words, keeping 20370 word types
# 2020-04-30 11:47:52,261: INFO: PROGRESS: at sentence #40000, processed 897814 words, keeping 23125 word types
# 2020-04-30 11:47:52,300: INFO: PROGRESS: at sentence #50000, processed 1116962 words, keeping 25365 word types
# 2020-04-30 11:47:52,337: INFO: PROGRESS: at sentence #60000, processed 1338403 words, keeping 27283 word types
# 2020-04-30 11:47:52,375: INFO: PROGRESS: at sentence #70000, processed 1561579 words, keeping 29024 word types
# 2020-04-30 11:47:52,412: INFO: PROGRESS: at sentence #80000, processed 1780886 words, keeping 30603 word types
# 2020-04-30 11:47:52,451: INFO: PROGRESS: at sentence #90000, processed 2004995 words, keeping 32223 word types
# 2020-04-30 11:47:52,489: INFO: PROGRESS: at sentence #100000, processed 2226966 words, keeping 33579 word types
# 2020-04-30 11:47:52,527: INFO: PROGRESS: at sentence #110000, processed 2446580 words, keeping 34827 word types
# 2020-04-30 11:47:52,567: INFO: PROGRESS: at sentence #120000, processed 2668775 words, keeping 36183 word types
# 2020-04-30 11:47:52,605: INFO: PROGRESS: at sentence #130000, processed 2894303 words, keeping 37353 word types
# 2020-04-30 11:47:52,643: INFO: PROGRESS: at sentence #140000, processed 3107005 words, keeping 38376 word types
# 2020-04-30 11:47:52,686: INFO: PROGRESS: at sentence #150000, processed 3332627 words, keeping 39556 word types
# 2020-04-30 11:47:52,736: INFO: PROGRESS: at sentence #160000, processed 3555315 words, keeping 40629 word types
# 2020-04-30 11:47:52,782: INFO: PROGRESS: at sentence #170000, processed 3778655 words, keeping 41628 word types
# 2020-04-30 11:47:52,820: INFO: PROGRESS: at sentence #180000, processed 3999236 words, keeping 42599 word types
# 2020-04-30 11:47:52,859: INFO: PROGRESS: at sentence #190000, processed 4224449 words, keeping 43461 word types
# 2020-04-30 11:47:52,900: INFO: PROGRESS: at sentence #200000, processed 4448603 words, keeping 44301 word types
# 2020-04-30 11:47:52,940: INFO: PROGRESS: at sentence #210000, processed 4669967 words, keeping 45212 word types
# 2020-04-30 11:47:52,979: INFO: PROGRESS: at sentence #220000, processed 4894968 words, keeping 46134 word types
# 2020-04-30 11:47:53,018: INFO: PROGRESS: at sentence #230000, processed 5117545 words, keeping 46986 word types
# 2020-04-30 11:47:53,057: INFO: PROGRESS: at sentence #240000, processed 5345050 words, keeping 47854 word types
# 2020-04-30 11:47:53,094: INFO: PROGRESS: at sentence #250000, processed 5559165 words, keeping 48699 word types
# 2020-04-30 11:47:53,132: INFO: PROGRESS: at sentence #260000, processed 5779146 words, keeping 49469 word types
# 2020-04-30 11:47:53,172: INFO: PROGRESS: at sentence #270000, processed 6000435 words, keeping 50416 word types
# 2020-04-30 11:47:53,214: INFO: PROGRESS: at sentence #280000, processed 6226314 words, keeping 51640 word types
# 2020-04-30 11:47:53,253: INFO: PROGRESS: at sentence #290000, processed 6449474 words, keeping 52754 word types
# 2020-04-30 11:47:53,293: INFO: PROGRESS: at sentence #300000, processed 6674077 words, keeping 53755 word types
# 2020-04-30 11:47:53,334: INFO: PROGRESS: at sentence #310000, processed 6899391 words, keeping 54734 word types
# 2020-04-30 11:47:53,373: INFO: PROGRESS: at sentence #320000, processed 7124278 words, keeping 55770 word types
# 2020-04-30 11:47:53,414: INFO: PROGRESS: at sentence #330000, processed 7346021 words, keeping 56687 word types
# 2020-04-30 11:47:53,455: INFO: PROGRESS: at sentence #340000, processed 7575533 words, keeping 57629 word types
# 2020-04-30 11:47:53,494: INFO: PROGRESS: at sentence #350000, processed 7798803 words, keeping 58485 word types
# 2020-04-30 11:47:53,534: INFO: PROGRESS: at sentence #360000, processed 8019466 words, keeping 59345 word types
# 2020-04-30 11:47:53,584: INFO: PROGRESS: at sentence #370000, processed 8246654 words, keeping 60161 word types
# 2020-04-30 11:47:53,626: INFO: PROGRESS: at sentence #380000, processed 8471801 words, keeping 61069 word types
# 2020-04-30 11:47:53,672: INFO: PROGRESS: at sentence #390000, processed 8701551 words, keeping 61810 word types
# 2020-04-30 11:47:53,716: INFO: PROGRESS: at sentence #400000, processed 8924500 words, keeping 62546 word types
# 2020-04-30 11:47:53,761: INFO: PROGRESS: at sentence #410000, processed 9145850 words, keeping 63263 word types
# 2020-04-30 11:47:53,804: INFO: PROGRESS: at sentence #420000, processed 9366930 words, keeping 64024 word types
# 2020-04-30 11:47:53,845: INFO: PROGRESS: at sentence #430000, processed 9594467 words, keeping 64795 word types
# 2020-04-30 11:47:53,887: INFO: PROGRESS: at sentence #440000, processed 9821218 words, keeping 65539 word types
# 2020-04-30 11:47:53,935: INFO: PROGRESS: at sentence #450000, processed 10044980 words, keeping 66378 word types
# 2020-04-30 11:47:53,979: INFO: PROGRESS: at sentence #460000, processed 10277740 words, keeping 67158 word types
# 2020-04-30 11:47:54,025: INFO: PROGRESS: at sentence #470000, processed 10505665 words, keeping 67775 word types
# 2020-04-30 11:47:54,067: INFO: PROGRESS: at sentence #480000, processed 10726049 words, keeping 68500 word types
# 2020-04-30 11:47:54,110: INFO: PROGRESS: at sentence #490000, processed 10952793 words, keeping 69256 word types
# 2020-04-30 11:47:54,151: INFO: PROGRESS: at sentence #500000, processed 11174449 words, keeping 69892 word types
# 2020-04-30 11:47:54,194: INFO: PROGRESS: at sentence #510000, processed 11399724 words, keeping 70593 word types
# 2020-04-30 11:47:54,236: INFO: PROGRESS: at sentence #520000, processed 11623075 words, keeping 71267 word types
# 2020-04-30 11:47:54,280: INFO: PROGRESS: at sentence #530000, processed 11847473 words, keeping 71877 word types
# 2020-04-30 11:47:54,325: INFO: PROGRESS: at sentence #540000, processed 12072088 words, keeping 72537 word types
# 2020-04-30 11:47:54,369: INFO: PROGRESS: at sentence #550000, processed 12297639 words, keeping 73212 word types
# 2020-04-30 11:47:54,408: INFO: PROGRESS: at sentence #560000, processed 12518929 words, keeping 73861 word types
# 2020-04-30 11:47:54,447: INFO: PROGRESS: at sentence #570000, processed 12748076 words, keeping 74431 word types
# 2020-04-30 11:47:54,487: INFO: PROGRESS: at sentence #580000, processed 12969572 words, keeping 75087 word types
# 2020-04-30 11:47:54,527: INFO: PROGRESS: at sentence #590000, processed 13195097 words, keeping 75733 word types
# 2020-04-30 11:47:54,568: INFO: PROGRESS: at sentence #600000, processed 13417295 words, keeping 76294 word types
# 2020-04-30 11:47:54,607: INFO: PROGRESS: at sentence #610000, processed 13638318 words, keeping 76952 word types
# 2020-04-30 11:47:54,645: INFO: PROGRESS: at sentence #620000, processed 13864643 words, keeping 77503 word types
# 2020-04-30 11:47:54,684: INFO: PROGRESS: at sentence #630000, processed 14088929 words, keeping 78066 word types
# 2020-04-30 11:47:54,724: INFO: PROGRESS: at sentence #640000, processed 14309712 words, keeping 78692 word types
# 2020-04-30 11:47:54,765: INFO: PROGRESS: at sentence #650000, processed 14535468 words, keeping 79295 word types
# 2020-04-30 11:47:54,805: INFO: PROGRESS: at sentence #660000, processed 14758258 words, keeping 79864 word types
# 2020-04-30 11:47:54,844: INFO: PROGRESS: at sentence #670000, processed 14981651 words, keeping 80381 word types
# 2020-04-30 11:47:54,883: INFO: PROGRESS: at sentence #680000, processed 15206483 words, keeping 80912 word types
# 2020-04-30 11:47:54,924: INFO: PROGRESS: at sentence #690000, processed 15428676 words, keeping 81482 word types
# 2020-04-30 11:47:54,963: INFO: PROGRESS: at sentence #700000, processed 15657382 words, keeping 82074 word types
# 2020-04-30 11:47:55,003: INFO: PROGRESS: at sentence #710000, processed 15880371 words, keeping 82560 word types
# 2020-04-30 11:47:55,042: INFO: PROGRESS: at sentence #720000, processed 16105658 words, keeping 83036 word types
# 2020-04-30 11:47:55,082: INFO: PROGRESS: at sentence #730000, processed 16332039 words, keeping 83571 word types
# 2020-04-30 11:47:55,120: INFO: PROGRESS: at sentence #740000, processed 16553072 words, keeping 84127 word types
# 2020-04-30 11:47:55,158: INFO: PROGRESS: at sentence #750000, processed 16771399 words, keeping 84599 word types
# 2020-04-30 11:47:55,198: INFO: PROGRESS: at sentence #760000, processed 16990803 words, keeping 85068 word types
# 2020-04-30 11:47:55,238: INFO: PROGRESS: at sentence #770000, processed 17217940 words, keeping 85644 word types
# 2020-04-30 11:47:55,278: INFO: PROGRESS: at sentence #780000, processed 17448086 words, keeping 86160 word types
# 2020-04-30 11:47:55,315: INFO: PROGRESS: at sentence #790000, processed 17675162 words, keeping 86665 word types
# 2020-04-30 11:47:55,338: INFO: collected 86996 word types from a corpus of 17798263 raw words and 795538 sentences
# 2020-04-30 11:47:55,339: INFO: Loading a fresh vocabulary
# 2020-04-30 11:47:55,389: INFO: effective_min_count=40 retains 11986 unique words (13% of original 86996, drops 75010)
# 2020-04-30 11:47:55,390: INFO: effective_min_count=40 leaves 17434026 word corpus (97% of original 17798263, drops 364237)
# 2020-04-30 11:47:55,426: INFO: deleting the raw counts dictionary of 86996 items
# 2020-04-30 11:47:55,429: INFO: sample=0.001 downsamples 50 most-common words
# 2020-04-30 11:47:55,430: INFO: downsampling leaves estimated 12872359 word corpus (73.8% of prior 17434026)
# 2020-04-30 11:47:55,460: INFO: estimated required memory for 11986 words and 300 dimensions: 34759400 bytes
# 2020-04-30 11:47:55,461: INFO: resetting layer weights
# 2020-04-30 11:47:57,694: INFO: training model with 4 workers on 11986 vocabulary and 300 features, using sg=0 hs=0 sample=0.001 negative=5 window=10
# 2020-04-30 11:47:58,701: INFO: EPOCH 1 - PROGRESS: at 8.67% examples, 1110371 words/s, in_qsize 7, out_qsize 0
# 2020-04-30 11:47:59,704: INFO: EPOCH 1 - PROGRESS: at 17.52% examples, 1117102 words/s, in_qsize 7, out_qsize 0
# 2020-04-30 11:48:00,704: INFO: EPOCH 1 - PROGRESS: at 26.25% examples, 1117882 words/s, in_qsize 7, out_qsize 0
# 2020-04-30 11:48:01,714: INFO: EPOCH 1 - PROGRESS: at 34.99% examples, 1115042 words/s, in_qsize 7, out_qsize 0
# 2020-04-30 11:48:02,723: INFO: EPOCH 1 - PROGRESS: at 43.87% examples, 1119640 words/s, in_qsize 7, out_qsize 0
# 2020-04-30 11:48:03,724: INFO: EPOCH 1 - PROGRESS: at 52.54% examples, 1119287 words/s, in_qsize 6, out_qsize 1
# 2020-04-30 11:48:04,725: INFO: EPOCH 1 - PROGRESS: at 60.97% examples, 1116051 words/s, in_qsize 7, out_qsize 0
# 2020-04-30 11:48:05,730: INFO: EPOCH 1 - PROGRESS: at 69.59% examples, 1114874 words/s, in_qsize 7, out_qsize 0
# 2020-04-30 11:48:06,738: INFO: EPOCH 1 - PROGRESS: at 78.43% examples, 1116823 words/s, in_qsize 7, out_qsize 0
# 2020-04-30 11:48:07,748: INFO: EPOCH 1 - PROGRESS: at 87.31% examples, 1118043 words/s, in_qsize 8, out_qsize 0
# 2020-04-30 11:48:08,752: INFO: EPOCH 1 - PROGRESS: at 96.36% examples, 1121695 words/s, in_qsize 7, out_qsize 0
# 2020-04-30 11:48:09,157: INFO: worker thread finished; awaiting finish of 3 more threads
# 2020-04-30 11:48:09,161: INFO: worker thread finished; awaiting finish of 2 more threads
# 2020-04-30 11:48:09,171: INFO: worker thread finished; awaiting finish of 1 more threads
# 2020-04-30 11:48:09,172: INFO: worker thread finished; awaiting finish of 0 more threads
# 2020-04-30 11:48:09,173: INFO: EPOCH - 1 : training on 17798263 raw words (12872726 effective words) took 11.5s, 1122000 effective words/s
# 2020-04-30 11:48:10,191: INFO: EPOCH 2 - PROGRESS: at 7.54% examples, 955582 words/s, in_qsize 7, out_qsize 0
# 2020-04-30 11:48:11,192: INFO: EPOCH 2 - PROGRESS: at 15.73% examples, 1000673 words/s, in_qsize 7, out_qsize 0
# 2020-04-30 11:48:12,199: INFO: EPOCH 2 - PROGRESS: at 24.67% examples, 1044750 words/s, in_qsize 7, out_qsize 0
# 2020-04-30 11:48:13,204: INFO: EPOCH 2 - PROGRESS: at 33.50% examples, 1063240 words/s, in_qsize 7, out_qsize 0
# 2020-04-30 11:48:14,205: INFO: EPOCH 2 - PROGRESS: at 42.14% examples, 1073959 words/s, in_qsize 7, out_qsize 0
# 2020-04-30 11:48:15,208: INFO: EPOCH 2 - PROGRESS: at 51.19% examples, 1089290 words/s, in_qsize 7, out_qsize 0
# 2020-04-30 11:48:16,212: INFO: EPOCH 2 - PROGRESS: at 60.12% examples, 1098985 words/s, in_qsize 7, out_qsize 0
# 2020-04-30 11:48:17,213: INFO: EPOCH 2 - PROGRESS: at 68.98% examples, 1104007 words/s, in_qsize 7, out_qsize 0
# 2020-04-30 11:48:18,216: INFO: EPOCH 2 - PROGRESS: at 77.60% examples, 1104529 words/s, in_qsize 7, out_qsize 0
# 2020-04-30 11:48:19,225: INFO: EPOCH 2 - PROGRESS: at 86.42% examples, 1106546 words/s, in_qsize 7, out_qsize 0
# 2020-04-30 11:48:20,231: INFO: EPOCH 2 - PROGRESS: at 95.47% examples, 1110991 words/s, in_qsize 7, out_qsize 0
# 2020-04-30 11:48:20,721: INFO: worker thread finished; awaiting finish of 3 more threads
# 2020-04-30 11:48:20,730: INFO: worker thread finished; awaiting finish of 2 more threads
# 2020-04-30 11:48:20,734: INFO: worker thread finished; awaiting finish of 1 more threads
# 2020-04-30 11:48:20,737: INFO: worker thread finished; awaiting finish of 0 more threads
# 2020-04-30 11:48:20,738: INFO: EPOCH - 2 : training on 17798263 raw words (12870874 effective words) took 11.6s, 1113425 effective words/s
# 2020-04-30 11:48:21,748: INFO: EPOCH 3 - PROGRESS: at 8.67% examples, 1106060 words/s, in_qsize 7, out_qsize 0
# 2020-04-30 11:48:22,755: INFO: EPOCH 3 - PROGRESS: at 17.75% examples, 1127249 words/s, in_qsize 7, out_qsize 0
# 2020-04-30 11:48:23,760: INFO: EPOCH 3 - PROGRESS: at 26.57% examples, 1127759 words/s, in_qsize 7, out_qsize 0
# 2020-04-30 11:48:24,765: INFO: EPOCH 3 - PROGRESS: at 35.39% examples, 1125502 words/s, in_qsize 8, out_qsize 0
# 2020-04-30 11:48:25,768: INFO: EPOCH 3 - PROGRESS: at 43.64% examples, 1113692 words/s, in_qsize 7, out_qsize 0
# 2020-04-30 11:48:26,775: INFO: EPOCH 3 - PROGRESS: at 51.25% examples, 1090385 words/s, in_qsize 7, out_qsize 0
# 2020-04-30 11:48:27,776: INFO: EPOCH 3 - PROGRESS: at 59.55% examples, 1089128 words/s, in_qsize 7, out_qsize 0
# 2020-04-30 11:48:28,777: INFO: EPOCH 3 - PROGRESS: at 67.57% examples, 1081947 words/s, in_qsize 7, out_qsize 0
# 2020-04-30 11:48:29,777: INFO: EPOCH 3 - PROGRESS: at 76.10% examples, 1083708 words/s, in_qsize 7, out_qsize 0
# 2020-04-30 11:48:30,780: INFO: EPOCH 3 - PROGRESS: at 84.56% examples, 1084129 words/s, in_qsize 7, out_qsize 0
# 2020-04-30 11:48:31,789: INFO: EPOCH 3 - PROGRESS: at 93.46% examples, 1089025 words/s, in_qsize 7, out_qsize 0
# 2020-04-30 11:48:32,543: INFO: worker thread finished; awaiting finish of 3 more threads
# 2020-04-30 11:48:32,553: INFO: worker thread finished; awaiting finish of 2 more threads
# 2020-04-30 11:48:32,557: INFO: worker thread finished; awaiting finish of 1 more threads
# 2020-04-30 11:48:32,561: INFO: worker thread finished; awaiting finish of 0 more threads
# 2020-04-30 11:48:32,561: INFO: EPOCH - 3 : training on 17798263 raw words (12873400 effective words) took 11.8s, 1089275 effective words/s
# 2020-04-30 11:48:33,570: INFO: EPOCH 4 - PROGRESS: at 8.72% examples, 1115923 words/s, in_qsize 7, out_qsize 0
# 2020-04-30 11:48:34,573: INFO: EPOCH 4 - PROGRESS: at 17.41% examples, 1108698 words/s, in_qsize 7, out_qsize 0
# 2020-04-30 11:48:35,576: INFO: EPOCH 4 - PROGRESS: at 26.13% examples, 1110848 words/s, in_qsize 7, out_qsize 0
# 2020-04-30 11:48:36,579: INFO: EPOCH 4 - PROGRESS: at 35.05% examples, 1117074 words/s, in_qsize 7, out_qsize 0
# 2020-04-30 11:48:37,584: INFO: EPOCH 4 - PROGRESS: at 43.58% examples, 1113564 words/s, in_qsize 7, out_qsize 0
# 2020-04-30 11:48:38,598: INFO: EPOCH 4 - PROGRESS: at 51.65% examples, 1098668 words/s, in_qsize 7, out_qsize 0
# 2020-04-30 11:48:39,603: INFO: EPOCH 4 - PROGRESS: at 60.47% examples, 1104829 words/s, in_qsize 7, out_qsize 0
# 2020-04-30 11:48:40,607: INFO: EPOCH 4 - PROGRESS: at 69.36% examples, 1109741 words/s, in_qsize 7, out_qsize 0
# 2020-04-30 11:48:41,610: INFO: EPOCH 4 - PROGRESS: at 77.66% examples, 1104880 words/s, in_qsize 7, out_qsize 0
# 2020-04-30 11:48:42,613: INFO: EPOCH 4 - PROGRESS: at 84.88% examples, 1087237 words/s, in_qsize 7, out_qsize 0
# 2020-04-30 11:48:43,614: INFO: EPOCH 4 - PROGRESS: at 93.57% examples, 1090014 words/s, in_qsize 7, out_qsize 0
# 2020-04-30 11:48:44,355: INFO: worker thread finished; awaiting finish of 3 more threads
# 2020-04-30 11:48:44,363: INFO: worker thread finished; awaiting finish of 2 more threads
# 2020-04-30 11:48:44,369: INFO: worker thread finished; awaiting finish of 1 more threads
# 2020-04-30 11:48:44,375: INFO: worker thread finished; awaiting finish of 0 more threads
# 2020-04-30 11:48:44,375: INFO: EPOCH - 4 : training on 17798263 raw words (12871439 effective words) took 11.8s, 1089998 effective words/s
# 2020-04-30 11:48:45,383: INFO: EPOCH 5 - PROGRESS: at 7.95% examples, 1015654 words/s, in_qsize 7, out_qsize 0
# 2020-04-30 11:48:46,386: INFO: EPOCH 5 - PROGRESS: at 15.62% examples, 997609 words/s, in_qsize 8, out_qsize 0
# 2020-04-30 11:48:47,398: INFO: EPOCH 5 - PROGRESS: at 23.21% examples, 983646 words/s, in_qsize 7, out_qsize 0
# 2020-04-30 11:48:48,406: INFO: EPOCH 5 - PROGRESS: at 31.03% examples, 986602 words/s, in_qsize 7, out_qsize 0
# 2020-04-30 11:48:49,409: INFO: EPOCH 5 - PROGRESS: at 39.07% examples, 995158 words/s, in_qsize 7, out_qsize 0
# 2020-04-30 11:48:50,413: INFO: EPOCH 5 - PROGRESS: at 47.89% examples, 1018435 words/s, in_qsize 7, out_qsize 0
# 2020-04-30 11:48:51,416: INFO: EPOCH 5 - PROGRESS: at 56.88% examples, 1038423 words/s, in_qsize 8, out_qsize 0
# 2020-04-30 11:48:52,420: INFO: EPOCH 5 - PROGRESS: at 65.68% examples, 1050655 words/s, in_qsize 7, out_qsize 0
# 2020-04-30 11:48:53,437: INFO: EPOCH 5 - PROGRESS: at 74.57% examples, 1059639 words/s, in_qsize 7, out_qsize 0
# 2020-04-30 11:48:54,446: INFO: EPOCH 5 - PROGRESS: at 83.17% examples, 1063095 words/s, in_qsize 7, out_qsize 0
# 2020-04-30 11:48:55,460: INFO: EPOCH 5 - PROGRESS: at 91.60% examples, 1064146 words/s, in_qsize 7, out_qsize 0
# 2020-04-30 11:48:56,405: INFO: worker thread finished; awaiting finish of 3 more threads
# 2020-04-30 11:48:56,410: INFO: worker thread finished; awaiting finish of 2 more threads
# 2020-04-30 11:48:56,416: INFO: worker thread finished; awaiting finish of 1 more threads
# 2020-04-30 11:48:56,421: INFO: worker thread finished; awaiting finish of 0 more threads
# 2020-04-30 11:48:56,422: INFO: EPOCH - 5 : training on 17798263 raw words (12872950 effective words) took 12.0s, 1069101 effective words/s
# 2020-04-30 11:48:56,422: INFO: training on a 88991315 raw words (64361389 effective words) took 58.7s, 1095928 effective words/s

# %%
# 학습이 완료 되면 필요없는 메모리를 unload 시킨다.
model.init_sims(replace=True)

model_name = '300features_40minwords_10text'
# model_name = '300features_50minwords_20text'
model.save(model_name)
# Out:
# 2020-04-30 11:48:56,429: INFO: precomputing L2-norms of word weight vectors
# 2020-04-30 11:48:56,442: INFO: saving Word2Vec object under 300features_40minwords_10text, separately None
# 2020-04-30 11:48:56,443: INFO: not storing attribute vectors_norm
# 2020-04-30 11:48:56,444: INFO: not storing attribute cum_table
# 2020-04-30 11:48:56,764: INFO: saved 300features_40minwords_10text

# %% [markdown]
# ## 모델 결과 탐색

# %%
# 유사도가 없는 단어 추출
model.wv.doesnt_match('man woman child kitchen'.split())
# Out:
# 'kitchen'

# %%
model.wv.doesnt_match("france england germany berlin".split())
# Out:
# 2020-04-30 11:48:56,882: WARNING: vectors for words {'germany', 'france'} are not present in the model, ignoring these words
# 'england'

# %%
# 가장 유사한 단어를 추출
model.wv.most_similar("man")
# Out:
# [('woman', 0.6439687013626099),
#  ('businessman', 0.50299072265625),
#  ('ladi', 0.5011154413223267),
#  ('billionair', 0.48935964703559875),
#  ('loner', 0.4878142178058624),
#  ('lad', 0.4874125123023987),
#  ('millionair', 0.4762689471244812),
#  ('farmer', 0.47465866804122925),
#  ('men', 0.4640536308288574),
#  ('doctor', 0.45357900857925415)]

# %%
model.wv.most_similar("queen")
# Out:
# [('princess', 0.624683678150177),
#  ('eva', 0.5687874555587769),
#  ('mistress', 0.56171053647995),
#  ('stepmoth', 0.5581921339035034),
#  ('goddess', 0.5580956339836121),
#  ('latifah', 0.5550867319107056),
#  ('bombshel', 0.5527088642120361),
#  ('madam', 0.5476841926574707),
#  ('brunett', 0.5389178395271301),
#  ('angela', 0.5367606282234192)]

# %%
model.wv.most_similar("film")
# Out:
# [('movi', 0.8557677268981934),
#  ('flick', 0.6096301078796387),
#  ('documentari', 0.5660871267318726),
#  ('pictur', 0.5537666082382202),
#  ('cinema', 0.5274899005889893),
#  ('it', 0.48840880393981934),
#  ('masterpiec', 0.48129579424858093),
#  ('sequel', 0.4780353009700775),
#  ('outing', 0.47714030742645264),
#  ('genr', 0.4756414294242859)]

# %%
#model.wv.most_similar("happy")
model.wv.most_similar("happi") # stemming 처리 시
# Out:
# [('unhappi', 0.4212590157985687),
#  ('bitter', 0.41711732745170593),
#  ('sad', 0.41446375846862793),
#  ('afraid', 0.3979133367538452),
#  ('satisfi', 0.39775803685188293),
#  ('glad', 0.37727090716362),
#  ('happier', 0.3730996251106262),
#  ('upset', 0.3724191188812256),
#  ('reward', 0.3672931492328644),
#  ('sappi', 0.3646870255470276)]

# %% [markdown]
# ### Word2Vec으로 벡터화 한 단어를 t-SNE 를 통해 시각화

# %%
# 참고 https://stackoverflow.com/questions/43776572/visualise-word2vec-generated-from-gensim
from sklearn.manifold import TSNE
import matplotlib as mpl
import matplotlib.pyplot as plt
import gensim 
import gensim.models as g

# 그래프에서 마이너스 폰트 깨지는 문제에 대한 대처
# mpl.rcParams['axes.unicode_minus'] = False

model_name = '300features_40minwords_10text'
model = g.Doc2Vec.load(model_name)

vocab = list(model.wv.vocab)
X = model[vocab]

print(len(X))
print(X[0][:10])
tsne = TSNE(n_components=2)

# 100개의 단어에 대해서만 시각화
X_tsne = tsne.fit_transform(X[:100,:])
# X_tsne = tsne.fit_transform(X)
# Out:
# 2020-04-30 00:53:42,084 : INFO : loading Doc2Vec object from 300features_40minwords_10text
# 2020-04-30 00:53:42,279 : INFO : loading wv recursively from 300features_40minwords_10text.wv.* with mmap=None
# 2020-04-30 00:53:42,280 : INFO : setting ignored attribute vectors_norm to None
# 2020-04-30 00:53:42,281 : INFO : loading vocabulary recursively from 300features_40minwords_10text.vocabulary.* with mmap=None
# 2020-04-30 00:53:42,281 : INFO : loading trainables recursively from 300features_40minwords_10text.trainables.* with mmap=None
# 2020-04-30 00:53:42,282 : INFO : setting ignored attribute cum_table to None
# 2020-04-30 00:53:42,282 : INFO : loaded 300features_40minwords_10text
# 11986
# [ 0.00980356  0.06309218  0.05619177 -0.07966041  0.05931453 -0.06673906
#  -0.02150377  0.06647947  0.08702882  0.00142203]

# %%
df = pd.DataFrame(X_tsne, index=vocab[:100], columns=['x', 'y'])
df.shape
# Out:
# (100, 2)

# %%
df.head(10)
# Out:
#                x          y
# with    2.823911  -9.014259
# all    -3.183646  -6.294578
# this   -0.505597  -2.188253
# stuff  -0.794164  -6.949909
# go      5.887387   0.091774
# down    4.398484 -11.293688
# at      5.728839  -9.630657
# the    -2.743879  -7.748000
# moment -5.781786  -5.001288
# mj     -1.763150 -12.215151

# %%
fig = plt.figure()
fig.set_size_inches(40, 20)
ax = fig.add_subplot(1, 1, 1)

ax.scatter(df['x'], df['y'])

for word, pos in df.iterrows():
    ax.annotate(word, pos, fontsize=30)
plt.show()

# %%
import numpy as np

def makeFeatureVec(words, model, num_features):
    """
    주어진 문장에서 단어 벡터의 평균을 구하는 함수
    """
    # 속도를 위해 0으로 채운 배열로 초기화 한다.
    featureVec = np.zeros((num_features,),dtype="float32")

    nwords = 0.
    # Index2word는 모델의 사전에 있는 단어명을 담은 리스트이다.
    # 속도를 위해 set 형태로 초기화 한다.
    index2word_set = set(model.wv.index2word)
    # 루프를 돌며 모델 사전에 포함이 되는 단어라면 피처에 추가한다.
    for word in words:
        if word in index2word_set:
            nwords = nwords + 1.
            featureVec = np.add(featureVec,model[word])
    # 결과를 단어수로 나누어 평균을 구한다.
    featureVec = np.divide(featureVec,nwords)
    return featureVec

# %%
def getAvgFeatureVecs(reviews, model, num_features):
    # 리뷰 단어 목록의 각각에 대한 평균 feature 벡터를 계산하고 
    # 2D numpy 배열을 반환한다.
    
    # 카운터를 초기화 한다.
    counter = 0.
    # 속도를 위해 2D 넘파이 배열을 미리 할당한다.
    reviewFeatureVecs = np.zeros(
        (len(reviews),num_features),dtype="float32")
    
    for review in reviews:
       # 매 1000개 리뷰마다 상태를 출력
        if counter%1000. == 0.:
            print("Review %d of %d" % (counter, len(reviews)))
       # 평균 피처 벡터를 만들기 위해 위에서 정의한 함수를 호출한다.
        reviewFeatureVecs[int(counter)] = makeFeatureVec(review, model, \
           num_features)
       # 카운터를 증가시킨다.
        counter = counter + 1.
    return reviewFeatureVecs

# %%
# 멀티스레드로 4개의 워커를 사용해 처리한다.
def getCleanReviews(reviews):
    clean_reviews = []
    clean_reviews = Word2VecUtil.apply_by_multiprocessing(\
        reviews["review"], Word2VecUtil.review_to_wordlist,\
        workers=4)
    return clean_reviews

# %%
# %time trainDataVecs = getAvgFeatureVecs(\
    getCleanReviews(train), model, num_features )
# Out:
# Review 0 of 25000
# Review 1000 of 25000
# Review 2000 of 25000
# Review 3000 of 25000
# Review 4000 of 25000
# Review 5000 of 25000
# Review 6000 of 25000
# Review 7000 of 25000
# Review 8000 of 25000
# Review 9000 of 25000
# Review 10000 of 25000
# Review 11000 of 25000
# Review 12000 of 25000
# Review 13000 of 25000
# Review 14000 of 25000
# Review 15000 of 25000
# Review 16000 of 25000
# Review 17000 of 25000
# Review 18000 of 25000
# Review 19000 of 25000
# Review 20000 of 25000
# Review 21000 of 25000
# Review 22000 of 25000
# Review 23000 of 25000
# Review 24000 of 25000
# CPU times: user 1min, sys: 972 ms, total: 1min 1s
# Wall time: 1min 33s

# %%
# %time testDataVecs = getAvgFeatureVecs(\
        getCleanReviews(test), model, num_features )
# Out:
# Review 0 of 25000
# Review 1000 of 25000
# Review 2000 of 25000
# Review 3000 of 25000
# Review 4000 of 25000
# Review 5000 of 25000
# Review 6000 of 25000
# Review 7000 of 25000
# Review 8000 of 25000
# Review 9000 of 25000
# Review 10000 of 25000
# Review 11000 of 25000
# Review 12000 of 25000
# Review 13000 of 25000
# Review 14000 of 25000
# Review 15000 of 25000
# Review 16000 of 25000
# Review 17000 of 25000
# Review 18000 of 25000
# Review 19000 of 25000
# Review 20000 of 25000
# Review 21000 of 25000
# Review 22000 of 25000
# Review 23000 of 25000
# Review 24000 of 25000
# CPU times: user 57.1 s, sys: 807 ms, total: 58 s
# Wall time: 1min 24s

# %% [markdown]
# ### 모델 생성

# %%
from sklearn.ensemble import RandomForestClassifier

forest = RandomForestClassifier(
    n_estimators = 100, n_jobs = -1, random_state=2018)

# %%
# %time forest = forest.fit( trainDataVecs, train["sentiment"] )
# Out:
# CPU times: user 1min 1s, sys: 166 ms, total: 1min 1s
# Wall time: 8.3 s

# %%
from sklearn.model_selection import cross_val_score
# %time score = np.mean(cross_val_score(\
    forest, trainDataVecs, \
    train['sentiment'], cv=10, scoring='roc_auc'))
# Out:
# CPU times: user 5.16 s, sys: 1.56 s, total: 6.73 s
# Wall time: 1min 26s

# %%
score
# Out:
# 0.9003752

# %% [markdown]
# ### Test

# %%
result = forest.predict( testDataVecs )

# %%
output = pd.DataFrame( data={"id":test["id"], "sentiment":result} )
output.to_csv('Word2Vec_AverageVectors_{0:.5f}.csv'.format(score), 
              index=False, quoting=3 )

# %%
output_sentiment = output['sentiment'].value_counts()
print(output_sentiment[0] - output_sentiment[1])
output_sentiment
# Out:
# 156
# 0    12578
# 1    12422
# Name: sentiment, dtype: int64

# %%
import seaborn as sns 
# %matplotlib inline

fig, axes = plt.subplots(ncols=2)
fig.set_size_inches(12,5)
sns.countplot(train['sentiment'], ax=axes[0])
sns.countplot(output['sentiment'], ax=axes[1])
