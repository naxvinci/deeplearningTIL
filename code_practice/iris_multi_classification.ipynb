# %%
# 꽃을 분류하는 작업

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from sklearn.preprocessing import LabelEncoder

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf

# %%
np.random.seed(3)
tf.random.set_seed(3)

# %%
df = pd.read_csv('./datasets/iris.csv', 
                 names = ["sepal_length", "sepal_width", 
                          "petal_length", "petal_width", "species"])

# %%
sns.pairplot(df, hue='species') # 종 별로 색을 주겠다
plt.figure(figsize=(10,5))
plt.show()

# %%
# 데이터 분류
dataset = df.values
x = dataset[:, 0:4].astype(float) # attribute
y_obj = dataset[:, 4] # class

# %%
# 문자열을 숫자로 변환
e = LabelEncoder()
e.fit(y_obj)
y= e.transform(y_obj)
y_encoded = tf.keras.utils.to_categorical(y)

# %%
print(type(e))
# Out:
# <class 'sklearn.preprocessing._label.LabelEncoder'>

# %%
#샘플 수 :150개
#속성 수 : 4
# -정보 1 : 꽃받침 길이(speal_length, 단위 : cm)
# -정보 2 : 꽃받침 넓이(sepal width, 단위 : cm)
# -정보 3 : 꽃잎 길이(petal length, 단위 : cm)
# -정보 4 : 꽃잎 넓이(petal width, 단위 : cm)
# 클래스 : iris-setosa, iris-versicolor, iris-virginica
