# %%
pip install plotly
# Out:
# ...
#      |████████████████████████████████| 7.1 MB 1.5 MB/s eta 0:00:01
# ...
# Processing /Users/dowon/Library/Caches/pip/wheels/d7/a9/33/acc7b709e2a35caa7d4cae442f6fe6fbf2c43f80823d46460c/retrying-1.3.3-cp37-none-any.whl
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import plotly as py
import plotly.graph_objs as go
import requests
from keras.layers import *
from keras.models import *
from keras.callbacks import *
from datetime import datetime
from sklearn.preprocessing import MinMaxScaler
plt.style.use('bmh')
# Out:
# Using TensorFlow backend.

# %%
''' 
https://poloniex.com/support/api/ 
https://poloniex.com/public?command=returnChartData&currencyPair=USDT_BTC&start=1414602755&end=9999999999&period=86400 
'''
# Out:
# ' \nhttps://poloniex.com/support/api/ \nhttps://poloniex.com/public?command=returnChartData&currencyPair=USDT_BTC&start=1414602755&end=9999999999&period=86400 \n'

# %%
ret = requests.get('https://poloniex.com/public?command=returnChartData&currencyPair=USDT_BTC&start=1414602755&end=9999999999&period=86400')
ret
# Out:
# <Response [200]>

# %%
js = ret.json()
js
# Out:
# [{'date': 1424304000,
#   'high': 244,
#   'low': 225,
#   'open': 225,
#   'close': 244,
#   'volume': 46.27631267,
#   'quoteVolume': 0.19311748,
#   'weightedAverage': 239.62777823},
#  {'date': 1424390400,
#   'high': 245,
#   'low': 240.25,
#   'open': 240.25011809,
#   'close': 240.25,
#   'volume': 55.894897,
#   'quoteVolume': 0.23042935,
#   'weightedAverage': 242.56847926},
#  {'date': 1424476800,
#   'high': 245,
#   'low': 245,
#   'open': 245,
#   'close': 245,
#   'volume': 14.72223865,
#   'quoteVolume': 0.06009077,
#   'weightedAverage': 245},
#  {'date': 1424563200,
#   'high': 249,
#   'low': 235,
#   'open': 245,
#   'close': 235,
#   'volume': 129.12124785,
#   'quoteVolume': 0.53905499,
#   'weightedAverage': 239.53260845},
#  {'date': 1424649600,
#   'high': 235.001,
#   'low': 235,
#   'open': 235.00000236,
#   'close': 235,
#   'volume': 96.56756248,
#   'quoteVolume': 0.41092569,
#   'weightedAverage': 235.00006166},
#  {'date': 1424736000,
# ...

# %%
df = pd.DataFrame(js)
df
# Out:
#             date         high          low         open        close  \
# 0     1424304000   244.000000   225.000000   225.000000   244.000000
# 1     1424390400   245.000000   240.250000   240.250118   240.250000
# 2     1424476800   245.000000   245.000000   245.000000   245.000000
# 3     1424563200   249.000000   235.000000   245.000000   235.000000
# 4     1424649600   235.001000   235.000000   235.000002   235.000000
# ...          ...          ...          ...          ...          ...
# 1889  1587513600  7151.789008  6819.720025  6842.936459  7124.344336
# 1890  1587600000  7723.000000  7026.310884  7126.024193  7553.060485
# 1891  1587686400  7605.555556  7397.041200  7551.384364  7502.897565
# 1892  1587772800  7696.659932  7439.124738  7503.323928  7538.715711
# 1893  1587859200  7700.000000  7483.682284  7538.715711  7600.084532
#
#             volume  quoteVolume  weightedAverage
# 0     4.627631e+01     0.193117       239.627778
# ...

# %%
scaler = MinMaxScaler()
df[['close']] = scaler.fit_transform(df[['close']])
df
# Out:
#             date         high          low         open     close  \
# 0     1424304000   244.000000   225.000000   225.000000  0.003428
# 1     1424390400   245.000000   240.250000   240.250118  0.003231
# 2     1424476800   245.000000   245.000000   245.000000  0.003480
# 3     1424563200   249.000000   235.000000   245.000000  0.002955
# 4     1424649600   235.001000   235.000000   235.000002  0.002955
# ...          ...          ...          ...          ...       ...
# 1889  1587513600  7151.789008  6819.720025  6842.936459  0.364709
# 1890  1587600000  7723.000000  7026.310884  7126.024193  0.387221
# 1891  1587686400  7605.555556  7397.041200  7551.384364  0.384587
# 1892  1587772800  7696.659932  7439.124738  7503.323928  0.386468
# 1893  1587859200  7700.000000  7483.682284  7538.715711  0.389690
#
#             volume  quoteVolume  weightedAverage
# 0     4.627631e+01     0.193117       239.627778
# 1     5.589490e+01     0.230429       242.568479
# ...

# %%
price = df['close'].values.tolist()
price
# Out:
# [0.0034278368698297933,
#  0.0032309273586996947,
#  0.0034803460727978203,
#  0.0029552540431175573,
#  0.0029552540431175573,
#  0.003204672757215681,
#  0.003099654351279629,
#  0.00313903625350565,
#  0.003690382884669925,
#  0.003217803221637167,
#  0.003795401290605977,
#  0.004740566944030449,
#  0.004647100562222272,
#  0.005318168176678739,
#  0.004110462809518489,
#  0.004267984117318213,
#  0.0042679843914162525,
#  0.004267985745628597,
#  0.004478021209064372,
#  0.0058957694093270275,
#  0.005108131365331727,
#  0.00510813142361694,
#  0.005061398178890919,
#  0.005060873101038725,
#  0.005428857595438652,
#  0.005055622161838608,
#  0.005055622163413884,
#  0.00437772835204648,
#  0.0045224602637016775,
#  0.004454960511881502,
#  0.004435645089785174,
#  0.004662687837208973,
#  0.004303349663071908,
#  0.003350412436521174,
#  0.0036103333860821093,
#  0.0033504120500534394,
#  0.003918939692428852,
#  0.00367612641447527,
#  0.00363626322497196,
# ...

# %%
'''
Many to Many
Many to One

X
(5, 1)
 0.057952922321361705,
 0.04047361277955355,
 0.0005532168396120696,
 0.02997810961897443,
 0.029365631586923735,
Y
(sample, 1)
'''

window_size = 5
X = []
Y = []

for i in range(len(price) - window_size):
    # i = 0
    # j = 0,1,2,3,4
    X.append([price[i + j] for j in range(window_size)])
    Y.append(price[window_size+i])

print(X)
print(Y)
# Out:
# [[0.0034278368698297933, 0.0032309273586996947, 0.0034803460727978203, 0.0029552540431175573, 0.0029552540431175573], [0.0032309273586996947, 0.0034803460727978203, 0.0029552540431175573, 0.0029552540431175573, 0.003204672757215681], [0.0034803460727978203, 0.0029552540431175573, 0.0029552540431175573, 0.003204672757215681, 0.003099654351279629], [0.0029552540431175573, 0.0029552540431175573, 0.003204672757215681, 0.003099654351279629, 0.00313903625350565], [0.0029552540431175573, 0.003204672757215681, 0.003099654351279629, 0.00313903625350565, 0.003690382884669925], [0.003204672757215681, 0.003099654351279629, 0.00313903625350565, 0.003690382884669925, 0.003217803221637167], [0.003099654351279629, 0.00313903625350565, 0.003690382884669925, 0.003217803221637167, 0.003795401290605977], [0.00313903625350565, 0.003690382884669925, 0.003217803221637167, 0.003795401290605977, 0.004740566944030449], [0.003690382884669925, 0.003217803221637167, 0.003795401290605977, 0.004740566944030449, 0.
# ...

# %%
X = np.asarray(X)
Y = np.asarray(Y)
print(X)
print(Y)
# Out:
# [[0.00342784 0.00323093 0.00348035 0.00295525 0.00295525]
#  [0.00323093 0.00348035 0.00295525 0.00295525 0.00320467]
#  [0.00348035 0.00295525 0.00295525 0.00320467 0.00309965]
#  ...
#  [0.36461633 0.34920784 0.34993273 0.36470923 0.38722078]
#  [0.34920784 0.34993273 0.36470923 0.38722078 0.38458676]
#  [0.34993273 0.36470923 0.38722078 0.38458676 0.38646754]]
# [0.00320467 0.00309965 0.00313904 ... 0.38458676 0.38646754 0.38968997]

# %%
X.shape
Y.shape
# Out:
# (1889,)

# %%
train_test_split = 1500
X_train = X[:train_test_split, :]
Y_train = Y[:train_test_split]

X_test = X[train_test_split:, :]
Y_test = Y[train_test_split:]

# %%
Y_train.shape
#X_test.shape
# Out:
# (1500,)

# %%
X_train[0]
# Out:
# array([0.00342784, 0.00323093, 0.00348035, 0.00295525, 0.00295525])

# %%
X_train = np.reshape(X_train, (X_train.shape[0], window_size, 1))
X_test = np.reshape(X_test, (X_test.shape[0], window_size, 1))

# Y_train = np.reshape(Y_train, (Y_train.shape[0], window_size, 1))
# Y_test = np.reshape(Y_test, (Y_test.shape[0], window_size, 1))

# %%
Y_train.shape
# Out:
# (1500,)

# %%
X_train[0]
# Out:
# array([[0.00342784],
#        [0.00323093],
#        [0.00348035],
#        [0.00295525],
#        [0.00295525]])

# %%
model = Sequential()
model.add(LSTM(128, input_shape=(5,1,)))
model.add(Dropout(0.2))
model.add(Dense(1, activation='linear'))
model.compile(loss='mse', optimizer='adam')
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# lstm_1 (LSTM)                (None, 128)               66560
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 129
# ...
# Total params: 66,689
# Trainable params: 66,689
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(X_train, Y_train, epochs=10, batch_size=1)
# Out:
# Epoch 1/10
# 1500/1500 [==============================] - 22s 15ms/step - loss: 0.0018
# Epoch 2/10
# 1500/1500 [==============================] - 20s 14ms/step - loss: 0.0012
# Epoch 3/10
# 1500/1500 [==============================] - 21s 14ms/step - loss: 0.0010
# Epoch 4/10
# 1500/1500 [==============================] - 22s 14ms/step - loss: 9.8963e-04
# Epoch 5/10
# 1500/1500 [==============================] - 23s 15ms/step - loss: 8.0216e-04
# Epoch 6/10
# 1500/1500 [==============================] - 23s 15ms/step - loss: 7.1690e-04
# Epoch 7/10
# 1500/1500 [==============================] - 23s 15ms/step - loss: 7.4933e-04
# Epoch 8/10
# 1500/1500 [==============================] - 23s 15ms/step - loss: 7.4659e-04
# Epoch 9/10
# 1500/1500 [==============================] - 22s 15ms/step - loss: 7.1442e-04
# Epoch 10/10
# 1500/1500 [==============================] - 23s 15ms/step - loss: 6.2816e-04

# %%
train_predict = model.predict(X_train)
test_predict = model.predict(X_test)

# %%
plt.figure(figsize= (10, 10))
plt.plot(price)

# %%
plt.figure(figsize= (15, 10))
plt.plot(price)

split_pt = train_test_split + window_size
# 1
plt.plot(np.arange(window_size, split_pt, 1), train_predict, color='g')

# 2
plt.plot(np.arange(split_pt, split_pt + len(test_predict), 1), test_predict, color='r')

# %%
# np.arange(window_size, split_pt, 1), train_predict
# plt.plot(np.arange(split_pt, split_pt + len(test_predict), 1), test_predict
trace = go.Scatter(x=np.arange(window_size, split_pt, 1), y = train_predict.reshape(1500), mode='lines', name='train')
trace2 = go.Scatter(x=np.arange(split_pt, split_pt + len(test_predict), 1), y = test_predict.reshape(389), mode='lines', name='test')
trace3 = go.Scatter(x=np.arange(1, len(price), 1), y = price, mode='lines', name='original')

data = [trace, trace2, trace3]
py.offline.plot(data)
# Out:
# 'temp-plot.html'
